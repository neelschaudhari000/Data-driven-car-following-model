# %% [markdown]
# Importing required libraries to predict acceleration using random forest, calculate RMSE (RootMeanSquaredError), and create plots to compare predicted and actual acceleration

# %%
import pandas as pd
import numpy as np

#import src
import FileProcessing
import ModelClass
# Out:
# original File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts
# Data File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data

# %% [markdown]
# Loading the cleaned ngsim data using pandas

# %%
model_obj=ModelClass.ModelClass()
file=FileProcessing.FileProcessing()

# %%
train_df_name ='train_df_cleaned_NGSIM'
test_df_name='test_df_cleaned_NGSIM'
val_df_name='val_df_cleaned_NGSIM'

train_df=file.read_input(train_df_name)
val_df=file.read_input(val_df_name)
test_df=file.read_input(test_df_name)
# Out:
# File Read Complete: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data/train_df_cleaned_NGSIM.csv
# File Read Complete: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data/val_df_cleaned_NGSIM.csv
# File Read Complete: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data/test_df_cleaned_NGSIM.csv

# %%
delta_time=0.1
train_df_0_1, val_df_0_1, test_df_0_1, X_train_0_1, y_train_0_1, X_val_0_1, y_val_0_1, X_test_0_1, y_test_0_1,predicted_data_0_1,model_0_1= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_0_1, 'cnn_train_df_0_1')

file.export_file(test_df_0_1, 'cnn_test_df_0_1')
file.export_file(X_train_0_1, 'cnn_X_train_0_1')
file.export_file(y_train_0_1, 'cnn_y_train_0_1')
file.export_file(X_test_0_1, 'cnn_X_test_0_1')
file.export_file(y_test_0_1, 'cnn_y_test_0_1')
file.export_file(val_df_0_1, 'cnn_val_df_0_1')
file.export_file(X_val_0_1, 'cnn_X_val_0_1')
file.export_file(y_val_0_1, 'cnn_y_val_0_1')
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization (BatchNo (None, 5, 16)             64
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...

# %%
delta_time=0.2
train_df_0_2, val_df_0_2, test_df_0_2, X_train_0_2, y_train_0_2, X_val_0_2, y_val_0_2, X_test_0_2, y_test_0_2,predicted_data_0_2,model_0_2= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_0_2, 'cnn_train_df_0_2')

file.export_file(test_df_0_2, 'cnn_test_df_0_2')
file.export_file(X_train_0_2, 'cnn_X_train_0_2')
file.export_file(y_train_0_2, 'cnn_y_train_0_2')
file.export_file(X_test_0_2, 'cnn_X_test_0_2')
file.export_file(y_test_0_2, 'cnn_y_test_0_2')
file.export_file(val_df_0_2, 'cnn_val_df_0_2')
file.export_file(X_val_0_2, 'cnn_X_val_0_2')
file.export_file(y_val_0_2, 'cnn_y_val_0_2')
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 16)             64
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...

# %%
delta_time=0.3
train_df_0_3, val_df_0_3, test_df_0_3, X_train_0_3, y_train_0_3, X_val_0_3, y_val_0_3, X_test_0_3, y_test_0_3,predicted_data_0_3,model_0_3= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_0_3, 'cnn_train_df_0_3')

file.export_file(test_df_0_3, 'cnn_test_df_0_3')
file.export_file(X_train_0_3, 'cnn_X_train_0_3')
file.export_file(y_train_0_3, 'cnn_y_train_0_3')
file.export_file(X_test_0_3, 'cnn_X_test_0_3')
file.export_file(y_test_0_3, 'cnn_y_test_0_3')
file.export_file(val_df_0_3, 'cnn_val_df_0_3')
file.export_file(X_val_0_3, 'cnn_X_val_0_3')
file.export_file(y_val_0_3, 'cnn_y_val_0_3')
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 16)             64
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...

# %%
delta_time=0.5
train_df_0_5, val_df_0_5, test_df_0_5, X_train_0_5, y_train_0_5, X_val_0_5, y_val_0_5, X_test_0_5, y_test_0_5,predicted_data_0_5,model_0_5= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_0_5, 'cnn_train_df_0_5')

file.export_file(test_df_0_5, 'cnn_test_df_0_5')
file.export_file(X_train_0_5, 'cnn_X_train_0_5')
file.export_file(y_train_0_5, 'cnn_y_train_0_5')
file.export_file(X_test_0_5, 'cnn_X_test_0_5')
file.export_file(y_test_0_5, 'cnn_y_test_0_5')
file.export_file(val_df_0_5, 'cnn_val_df_0_5')
file.export_file(X_val_0_5, 'cnn_X_val_0_5')
file.export_file(y_val_0_5, 'cnn_y_val_0_5')
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 16)             64
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...

# %%
delta_time=1
train_df_1, val_df_1, test_df_1, X_train_1, y_train_1, X_val_1, y_val_1, X_test_1, y_test_1,predicted_data_1,model_1= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_1, 'cnn_train_df_1')

file.export_file(test_df_1, 'cnn_test_df_1')
file.export_file(X_train_1, 'cnn_X_train_1')
file.export_file(y_train_1, 'cnn_y_train_1')
file.export_file(X_test_1, 'cnn_X_test_1')
file.export_file(y_test_1, 'cnn_y_test_1')
file.export_file(val_df_1, 'cnn_val_df_1')
file.export_file(X_val_1, 'cnn_X_val_1')
file.export_file(y_val_1, 'cnn_y_val_1')
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 16)             64
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...

# %%
delta_time=2
train_df_2, val_df_2, test_df_2, X_train_2, y_train_2, X_val_2, y_val_2, X_test_2, y_test_2,predicted_data_2,model_2= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_2, 'cnn_train_df_2')

file.export_file(test_df_2, 'cnn_test_df_2')
file.export_file(X_train_2, 'cnn_X_train_2')
file.export_file(y_train_2, 'cnn_y_train_2')
file.export_file(X_test_2, 'cnn_X_test_2')
file.export_file(y_test_2, 'cnn_y_test_2')
file.export_file(val_df_2, 'cnn_val_df_2')
file.export_file(X_val_2, 'cnn_X_val_2')
file.export_file(y_val_2, 'cnn_y_val_2')
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 5, 16)             64
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...

# %%
delta_time=4
train_df_4, val_df_4, test_df_4, X_train_4, y_train_4, X_val_4, y_val_4, X_test_4, y_test_4,predicted_data_4,model_4= model_obj.fit_and_run_neural(train_df,val_df,test_df, delta_time)

file.export_file(train_df_4, 'cnn_train_df_4')

file.export_file(test_df_4, 'cnn_test_df_4')
file.export_file(X_train_4, 'cnn_X_train_4')
file.export_file(y_train_4, 'cnn_y_train_4')
file.export_file(X_test_4, 'cnn_X_test_4')
file.export_file(y_test_4, 'cnn_y_test_4')
file.export_file(val_df_4, 'cnn_val_df_4')
file.export_file(X_val_4, 'cnn_X_val_4')
file.export_file(y_val_4, 'cnn_y_val_4')
# Out:
# Model: "functional_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_7 (InputLayer)         [(None, 5, 1)]            0
# _________________________________________________________________
# Block1_Conv1 (Conv1D)        (None, 5, 16)             48
# _________________________________________________________________
# Block1_Conv2 (Conv1D)        (None, 5, 16)             528
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 5, 16)             64
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 5, 16)             0
# _________________________________________________________________
# Block2_Conv1 (Conv1D)        (None, 5, 32)             1056
# _________________________________________________________________
# Block2_Conv2 (Conv1D)        (None, 5, 32)             2080
# ...
