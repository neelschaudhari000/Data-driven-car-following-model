# %% [markdown]
# This notebook Executes, Fit and Store the various Models for multiple Reaction times for KNN Model.
#
# Input: Training and Test Dataframe.
#
# Output: Various Models in Scripts Folder. Various files for train, test, prediction samples in Data folder.

# %%
import pandas as pd
import numpy as np

#import src
import FileProcessing
import ModelClass
# Out:
# original File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\scripts
# Data File path: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data

# %%
fileProcessing=FileProcessing.FileProcessing()

# %%
model_obj=ModelClass.ModelClass()
file=FileProcessing.FileProcessing()

# %%
train_df_name ='train_df_cleaned_NGSIM'
test_df_name='test_df_cleaned_NGSIM'

train_df=fileProcessing.read_input(train_df_name)
test_df=fileProcessing.read_input(test_df_name)
# Out:
# File Read Complete: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data/train_df_cleaned_NGSIM.csv
# File Read Complete: c:\Users\StudentAccount\Python\Capstone\gitcodelocation\DataDrivenCarFollowing\datadrivencarfollowing-v1\data/test_df_cleaned_NGSIM.csv

# %%
delta_time=0.1
train_df_0_1, test_df_0_1, X_train_0_1, y_train_0_1, X_test_0_1, y_test_0_1,predicted_data_0_1,model_0_1= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)


file.export_file(train_df_0_1, 'knn_train_df_0_1')
file.export_file(test_df_0_1, 'knn_test_df_0_1')
file.export_file(X_train_0_1, 'knn_X_train_0_1')
file.export_file(y_train_0_1, 'knn_y_train_0_1')
file.export_file(X_test_0_1, 'knn_X_test_0_1')
file.export_file(y_test_0_1, 'knn_y_test_0_1')
# Out:
# Prediction being done on :328-342
# True

# %%
delta_time=0.2
train_df_0_2, test_df_0_2, X_train_0_2, y_train_0_2, X_test_0_2, y_test_0_2,predicted_data_0_2,model_0_2= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)

file.export_file(train_df_0_2, 'knn_train_df_0_2')
file.export_file(test_df_0_2, 'knn_test_df_0_2')
file.export_file(X_train_0_2, 'knn_X_train_0_2')
file.export_file(y_train_0_2, 'knn_y_train_0_2')
file.export_file(X_test_0_2, 'knn_X_test_0_2')
file.export_file(y_test_0_2, 'knn_y_test_0_2')
# Out:
# Prediction being done on :328-342
# True

# %%
delta_time=0.3
train_df_0_3, test_df_0_3, X_train_0_3, y_train_0_3, X_test_0_3, y_test_0_3,predicted_data_0_3,model_0_3= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)


file.export_file(train_df_0_3, 'knn_train_df_0_3')
file.export_file(test_df_0_3, 'knn_test_df_0_3')

file.export_file(X_train_0_3, 'knn_X_train_0_3')
file.export_file(y_train_0_3, 'knn_y_train_0_3')

file.export_file(X_test_0_3, 'knn_X_test_0_3')
file.export_file(y_test_0_3, 'knn_y_test_0_3')
# Out:
# Prediction being done on :328-342
# True

# %%
delta_time=0.5
train_df_0_5, test_df_0_5, X_train_0_5, y_train_0_5, X_test_0_5, y_test_0_5,predicted_data_0_5,model_0_5= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)

file.export_file(train_df_0_5, 'knn_train_df_0_5')
file.export_file(test_df_0_5, 'knn_test_df_0_5')

file.export_file(X_train_0_5, 'knn_X_train_0_5')
file.export_file(y_train_0_5, 'knn_y_train_0_5')

file.export_file(X_test_0_5, 'knn_X_test_0_5')
file.export_file(y_test_0_5, 'knn_y_test_0_5')
# Out:
# Prediction being done on :328-342
# True

# %%
delta_time=1
train_df_1, test_df_1, X_train_1, y_train_1, X_test_1, y_test_1,predicted_data_1,model_1= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)

file.export_file(train_df_1, 'knn_train_df_1')
file.export_file(test_df_1, 'knn_test_df_1')

file.export_file(X_train_1, 'knn_X_train_1')
file.export_file(y_train_1, 'knn_y_train_1')

file.export_file(X_test_1, 'knn_X_test_1')
file.export_file(y_test_1, 'knn_y_test_1')
# Out:
# Prediction being done on :328-342
# True

# %%
delta_time=2
train_df_2, test_df_2, X_train_2, y_train_2, X_test_2, y_test_2,predicted_data_2,model_2= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)

file.export_file(train_df_2, 'knn_train_df_2')
file.export_file(test_df_2, 'knn_test_df_2')

file.export_file(X_train_2, 'knn_X_train_2')
file.export_file(y_train_2, 'knn_y_train_2')

file.export_file(X_test_2, 'knn_X_test_2')
file.export_file(y_test_2, 'knn_y_test_2')
# Out:
# Prediction being done on :328-342
# True

# %%
delta_time=4
train_df_4, test_df_4, X_train_4, y_train_4, X_test_4, y_test_4,predicted_data_4,model_4= model_obj.fit_and_run_KNN(train_df,test_df, delta_time)

file.export_file(train_df_4, 'knn_train_df_4')
file.export_file(test_df_4, 'knn_test_df_4')

file.export_file(X_train_4, 'knn_X_train_4')
file.export_file(y_train_4, 'knn_y_train_4')

file.export_file(X_test_4, 'knn_X_test_4')
file.export_file(y_test_4, 'knn_y_test_4')
# Out:
# Prediction being done on :328-342
# True
